# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import spotipy 
import requests
import time, os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()
chromedriver = "/usr/bin/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
query = 'Stick Figure'
youtube_search = "https://www.youtube.com/results?search_query="
youtube_query = youtube_search + query.replace(' ', '+')

# %%
page = requests.get(youtube_query).text
soup = BeautifulSoup(page, 'html5lib')

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(youtube_query)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en-US"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="icon" sizes="16x16" href="//cdn.otstatic.com/cfe/4/images/favicon-16-eec075.png"><link rel="icon" sizes="32x32" href="//cdn.otstatic.com/cfe/4/images/favicon-32-76aa16.png"><link rel="icon" sizes="48x48" href="//cdn.otstatic.com/cfe/4/images/favicon-48-b39a55.png"><link rel="icon" sizes="64x64" href="//cdn.otstatic.com/cfe/4/images/favicon-64-ee0fa3.png"><link rel="icon" sizes="128x128" href="//cdn.otstatic.com/cfe/4/images/favicon-128-d256f1.png"><title>Restaurants and Restaurant Reservations | OpenTable</title><meta name="description" content="Make online reservations, read restaurant reviews from diners, and earn points towards free meals. OpenTable is a real-time online reservation network for fine dining restaurants."><meta name="keywords" content="restaurant reservations, online restaurant reservations, restaurant management software, opentable, open table'

# %%
soup =  BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find('div', id='contents')
# Out:
# <div class="style-scope ytd-section-list-renderer" id="contents"><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=l30SXoUcXUE" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/l30SXoUcXUE/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLDZiX4RfmtlDUfGiSK0t720CQVnJw" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="1 hour, 6 minutes, 29 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       1:06:29
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label='Stick Figure – "World on Fire" (Full Album) by Stick Figure 10 months ago 1 hour, 6 minutes 1,793,496 views' class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=l30SXoUcXUE" id="video-title" title='Stick Figure – "World on Fire" (Full Album)'>
# <yt-formatted-string aria-label='Stick Figure – "World on Fire" (Full Album) by Stick Figure 10 months ago 1 hour, 6 minutes 1,793,496 views' class="style-scope ytd-video-renderer">Stick Figure – "World on Fire" (Full Album)</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" style="left: 246px; right: auto; top: -36px; bottom: auto;" tabindex="-1"><!--css-build:shady-->
# <div class="style-scope paper-tooltip hidden" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">1.7M views</span>
# <span class="style-scope ytd-video-meta-block">10 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">New album "World on Fire" out NOW. Listen here: https://fanlink.to/worldonfire http://www.</span><span class="bold style-scope yt-formatted-string" dir="auto">stickfigure</span><span class="style-scope yt-formatted-string" dir="auto">.com ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-radio-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <ytd-thumbnail class="style-scope ytd-radio-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=UL6GEX47Nk8&amp;list=RDEMt3s0Hphv0AIco73O63LcOw&amp;start_radio=1" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/UL6GEX47Nk8/hqdefault.jpg?sqp=-oaymwEXCPYBEIoBSFryq4qpAwkIARUAAIhCGAE=&amp;rs=AOn4CLDU6vZo8HVqGlt7mgDE9fK2fqLrWA" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-side-panel-renderer class="style-scope ytd-thumbnail" style="width: 108px;"><!--css-build:shady-->
# <yt-formatted-string class="style-scope ytd-thumbnail-overlay-side-panel-renderer">50+</yt-formatted-string>
# <yt-icon class="style-scope ytd-thumbnail-overlay-side-panel-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M16.94 6.9l-1.4 1.46C16.44 9.3 17 10.58 17 12s-.58 2.7-1.48 3.64l1.4 1.45C18.22 15.74 19 13.94 19 12s-.8-3.8-2.06-5.1zM23 12c0-3.12-1.23-5.95-3.23-8l-1.4 1.45C19.97 7.13 21 9.45 21 12s-1 4.9-2.64 6.55l1.4 1.45c2-2.04 3.24-4.87 3.24-8zM7.06 17.1l1.4-1.46C7.56 14.7 7 13.42 7 12s.6-2.7 1.5-3.64L7.08 6.9C5.78 8.2 5 10 5 12s.8 3.8 2.06 5.1zM1 12c0 3.12 1.23 5.95 3.23 8l1.4-1.45C4.03 16.87 3 14.55 3 12s1-4.9 2.64-6.55L4.24 4C2.24 6.04 1 8.87 1 12zm9-3.32v6.63l5-3.3-5-3.3z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </ytd-thumbnail-overlay-side-panel-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="style-scope ytd-radio-renderer" id="content">
# <a class="yt-simple-endpoint style-scope ytd-radio-renderer" href="/watch?v=UL6GEX47Nk8&amp;list=RDEMt3s0Hphv0AIco73O63LcOw&amp;start_radio=1">
# <h3 class="style-scope ytd-radio-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-radio-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <span class="style-scope ytd-radio-renderer" id="video-title" title="Mix - Stick Figure">
#             Mix - Stick Figure
#           </span>
# </h3>
# <ytd-video-meta-block class="style-scope ytd-radio-renderer" id="meta"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""><!--css-build:shady--></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </a>
# <ul class="style-scope ytd-radio-renderer" id="list">
# <li class="style-scope ytd-radio-renderer">
# <ytd-child-video-renderer class="style-scope ytd-radio-renderer"><!--css-build:shady--><a class="yt-simple-endpoint style-scope ytd-child-video-renderer" href="/watch?v=UL6GEX47Nk8&amp;list=RDEMt3s0Hphv0AIco73O63LcOw&amp;start_radio=1" id="title"><yt-formatted-string class="style-scope ytd-child-video-renderer" ellipsis-truncate="" id="video-title" title='Stick Figure – "Sound of the Sea" (Official Music Video)'>Stick Figure – "Sound of the Sea" (Official Music Video)</yt-formatted-string></a><div class="style-scope ytd-child-video-renderer" id="length">5:41</div></ytd-child-video-renderer>
# </li>
# <li class="style-scope ytd-radio-renderer">
# <ytd-child-video-renderer class="style-scope ytd-radio-renderer"><!--css-build:shady--><a class="yt-simple-endpoint style-scope ytd-child-video-renderer" href="/watch?v=fp9c3d7Gy9o&amp;list=RDEMt3s0Hphv0AIco73O63LcOw&amp;start_radio=1" id="title"><yt-formatted-string class="style-scope ytd-child-video-renderer" ellipsis-truncate="" id="video-title" title="Stick Figure - Weight of Sound">Stick Figure - Weight of Sound</yt-formatted-string></a><div class="style-scope ytd-child-video-renderer" id="length">7:24</div></ytd-child-video-renderer>
# </li>
# <dom-repeat as="video" class="style-scope ytd-radio-renderer"><template is="dom-repeat"></template></dom-repeat>
# </ul>
# </div>
# </ytd-radio-renderer><ytd-channel-renderer class="style-scope ytd-item-section-renderer" prominent-thumb-style="DEFAULT" style="background-color: transparent;"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-channel-renderer" hidden="" id="channel-user-state"><!--css-build:shady--></yt-formatted-string><div class="style-scope ytd-channel-renderer" id="content-section"><div class="style-scope ytd-channel-renderer" id="avatar-section"><a class="channel-link yt-simple-endpoint style-scope ytd-channel-renderer" href="/user/roughwood23"><div class="style-scope ytd-channel-renderer" id="avatar"><yt-img-shadow class="style-scope ytd-channel-renderer no-transition" height="136" loaded="" style="background-color: transparent;" width="136"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" height="136" id="img" src="//lh3.googleusercontent.com/a-/AOh14GiqarfUjsFAM-AQQ_eIgt0EV2Asu0-Zj01DP5qrWw=s176-c-k-c0x00ffffff-no-rj-mo" width="136"/></yt-img-shadow></div></a></div><div class="style-scope ytd-channel-renderer" id="info-section"><a class="channel-link yt-simple-endpoint style-scope ytd-channel-renderer" href="/user/roughwood23" id="main-link"><div class="style-scope ytd-channel-renderer" id="info"><ytd-channel-name class="style-scope ytd-channel-renderer" id="channel-title" wrap-text=""><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" id="text" title="">Stick Figure</yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" style="left: 283.016px; right: auto; top: 332px; bottom: auto;" tabindex="-1"><!--css-build:shady-->
# <div class="style-scope paper-tooltip hidden" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name><div class="style-scope ytd-channel-renderer" id="metadata"><span class="style-scope ytd-channel-renderer" id="subscribers">257K subscribers</span><span class="style-scope ytd-channel-renderer" id="dot">•</span><span class="style-scope ytd-channel-renderer" id="video-count">143 videos</span></div><yt-formatted-string class="style-scope ytd-channel-renderer" id="description"><span class="style-scope yt-formatted-string" dir="auto">Official </span><span class="bold style-scope yt-formatted-string" dir="auto">Stick Figure</span><span class="style-scope yt-formatted-string" dir="auto"> Youtube channel. New album "World on Fire" out now https://www.stickfiguremusic.com/ #</span><span class="bold style-scope yt-formatted-string" dir="auto">stickfigure</span><span class="style-scope yt-formatted-string" dir="auto"> ...</span></yt-formatted-string></div><div class="style-scope ytd-channel-renderer" hidden="" id="navigation-icon"><yt-icon class="style-scope ytd-channel-renderer" disable-upgrade=""></yt-icon></div></a><div class="style-scope ytd-channel-renderer" id="subscribe-button"><ytd-button-renderer button-renderer="" class="style-scope ytd-channel-renderer style-destructive size-default" is-paper-button="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fresults%253Fsearch_query%253DStick%252BFigure%26continue_action%&amp;hl=en" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="Subscribe" class="style-scope ytd-button-renderer style-destructive size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-destructive size-default" id="text">Subscribe</yt-formatted-string></paper-button></a></ytd-button-renderer></div></div></div></ytd-channel-renderer><ytd-shelf-renderer class="style-scope ytd-item-section-renderer" thumbnail-style=""><!--css-build:shady-->
# <div class="style-scope ytd-shelf-renderer" id="dismissable">
# <div class="grid-subheader style-scope ytd-shelf-renderer">
# <div class="style-scope ytd-shelf-renderer" id="title-container">
# <h2 class="style-scope ytd-shelf-renderer">
# <yt-icon class="style-scope ytd-shelf-renderer" disable-upgrade="" hidden="" id="icon">
# </yt-icon>
# <span class="style-scope ytd-shelf-renderer" id="title">Latest from Stick Figure</span>
# <dom-if class="style-scope ytd-shelf-renderer"><template is="dom-if"></template></dom-if>
# <dom-if class="style-scope ytd-shelf-renderer"><template is="dom-if"></template></dom-if>
# <ytd-badge-supported-renderer class="style-scope ytd-shelf-renderer" disable-upgrade="" hidden="" id="featured-badge">
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-shelf-renderer" id="title-annotation"><!--css-build:shady--></yt-formatted-string>
# <div class="style-scope ytd-shelf-renderer" id="play-button"></div>
# <div class="style-scope ytd-shelf-renderer" id="sort-filter"></div>
# </h2>
# <div class="style-scope ytd-shelf-renderer" id="spacer"></div>
# <div class="style-scope ytd-shelf-renderer" id="subscribe-button"></div>
# <div class="style-scope ytd-shelf-renderer" id="menu"></div>
# </div>
# <yt-formatted-string class="can-be-empty style-scope ytd-shelf-renderer" id="subtitle"><!--css-build:shady--></yt-formatted-string>
# </div>
# <div class="style-scope ytd-shelf-renderer" id="contents"><ytd-vertical-list-renderer class="style-scope ytd-shelf-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-vertical-list-renderer" id="items"><ytd-video-renderer class="style-scope ytd-vertical-list-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=M0vcZWuCD04" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/M0vcZWuCD04/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLBqS6G9G6z33iV380D2-ngSSTdwVg" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="1 minute, 44 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       1:44
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label='Stick Figure – "Free Flow Sessions - June 2020" by Stick Figure 4 weeks ago 1 minute, 44 seconds 43,940 views' class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=M0vcZWuCD04" id="video-title" title='Stick Figure – "Free Flow Sessions - June 2020"'>
# <yt-formatted-string aria-label='Stick Figure – "Free Flow Sessions - June 2020" by Stick Figure 4 weeks ago 1 minute, 44 seconds 43,940 views' class="style-scope ytd-video-renderer">Stick Figure – "Free Flow Sessions - June 2020"</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">43K views</span>
# <span class="style-scope ytd-video-meta-block">4 weeks ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">Free Flow Sessions - June 2020 Back at it with a brand new Free Flow Session. Recorded here at </span><span class="bold style-scope yt-formatted-string" dir="auto">Stick Figure's</span><span class="style-scope yt-formatted-string" dir="auto"> own Great Stone ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">4K</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-vertical-list-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=Tlugb0xR5Nc" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/Tlugb0xR5Nc/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLALABnx90qjVLCffRRuV0tRJnQiDw" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="1 minute, 14 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       1:14
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Keedron Bryant - I Just Wanna Live (Reggae Version) by Stick Figure 1 month ago 1 minute, 14 seconds 85,574 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=Tlugb0xR5Nc" id="video-title" title="Keedron Bryant - I Just Wanna Live (Reggae Version)">
# <yt-formatted-string aria-label="Keedron Bryant - I Just Wanna Live (Reggae Version) by Stick Figure 1 month ago 1 minute, 14 seconds 85,574 views" class="style-scope ytd-video-renderer">Keedron Bryant - I Just Wanna Live (Reggae Version)</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">85K views</span>
# <span class="style-scope ytd-video-meta-block">1 month ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">Powerful words from a young black man, Keedron Bryant (https://www.youtube.com/channel/UCJvR2QWXfYBeov-7Y-Fw2Fw).</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer></div>
# <div class="style-scope ytd-vertical-list-renderer" id="more">
# <yt-formatted-string aria-label="+8 more" class="style-scope ytd-vertical-list-renderer"><span class="style-scope yt-formatted-string" dir="auto">+</span><span class="style-scope yt-formatted-string" dir="auto">8</span><span class="style-scope yt-formatted-string" dir="auto"> more</span></yt-formatted-string>
# </div>
# <div class="style-scope ytd-vertical-list-renderer" hidden="" id="all">
# <a class="yt-simple-endpoint style-scope ytd-vertical-list-renderer" href$="[[computeHref_(data.expandedStateButtonEndpoint]]">
# <yt-formatted-string class="style-scope ytd-vertical-list-renderer"><!--css-build:shady--></yt-formatted-string>
# </a>
# </div>
# </ytd-vertical-list-renderer></div>
# </div>
# <div class="style-scope ytd-shelf-renderer" id="dismissed"></div>
# </ytd-shelf-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=bU_CrTrZDnY" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/bU_CrTrZDnY/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLBt398rR9KjNDS1SOzukPCZAN50vA" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="1 hour, 0 minutes, 9 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       1:00:09
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Stick Figure / Set in Stone (Full Album) by Der Analoge Kompromiss 4 years ago 1 hour 4,852,552 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=bU_CrTrZDnY" id="video-title" title="Stick Figure / Set in Stone (Full Album)">
# <yt-formatted-string aria-label="Stick Figure / Set in Stone (Full Album) by Der Analoge Kompromiss 4 years ago 1 hour 4,852,552 views" class="style-scope ytd-video-renderer">Stick Figure / Set in Stone (Full Album)</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# ...
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">2.2M views</span>
# <span class="style-scope ytd-video-meta-block">2 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">New album "World on Fire" out NOW. Listen here: https://fanlink.to/worldonfire http://www.</span><span class="bold style-scope yt-formatted-string" dir="auto">stickfigure</span><span class="style-scope yt-formatted-string" dir="auto">.com ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">4K</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=xV-lMtisZw0" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="5 minutes, 7 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       5:07
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label='Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio] by Stick Figure 4 years ago 5 minutes, 7 seconds 9,438,718 views' class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=xV-lMtisZw0" id="video-title" title='Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio]'>
# <yt-formatted-string aria-label='Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio] by Stick Figure 4 years ago 5 minutes, 7 seconds 9,438,718 views' class="style-scope ytd-video-renderer">Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio]</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">9.4M views</span>
# <span class="style-scope ytd-video-meta-block">4 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCjiiFG9kMvhSSvvWMzgXCOw" spellcheck="false">Stick Figure</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Stick Figure
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified-artist style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon" viewbox="0 0 24 24">
# <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none"></path>
# <path class="style-scope yt-icon" d="M12 3v10.55c-.59-.34-1.27-.55-2-.55-2.21 0-4 1.79-4 4s1.79 4 4 4 4-1.79 4-4V7h4V3h-6z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Official Artist Channel
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">New album "World on Fire" out NOW. Listen here: https://fanlink.to/worldonfire Download on iTunes: http://msclvr.co/w0lBGD ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"><yt-next-continuation class="style-scope ytd-item-section-renderer"><!--css-build:shady-->
# <paper-spinner aria-hidden="true" class="style-scope yt-next-continuation" id="spinner"><!--css-build:shady--><div class="style-scope paper-spinner" id="spinnerContainer"><div class="spinner-layer layer-1 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-2 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-3 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-4 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div></div></paper-spinner>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# </yt-next-continuation></div>
# </ytd-item-section-renderer></div>

# %%
contents_div = soup.find('div', id='contents')

for title in contents_div.find_all('a', id='video-title'):
    print(title.text.strip())
# Out:
# Stick Figure – "World on Fire" (Full Album)
# Stick Figure – "Free Flow Sessions - June 2020"
# Keedron Bryant - I Just Wanna Live (Reggae Version)
# Stick Figure / Set in Stone (Full Album)
# Stick Figure – "Angels Above Me" (Official Music Video)
# Stick Figure – "Sound of the Sea" (Official Music Video)
# Stick Figure – "All for You" (Official Music Video)
# Weight of Sound
# Stick Figure - Weight of Sound
# Stick Figure – "Sentenced"
# Stick Figure – "Shine"
# Stick Figure - Heartland
# Stick Figure – "Fire on the Horizon" (Official Music Video)
# Stick Figure – "Once in a Lifetime"
# STICK FIGURE Full Concert at Levitate Music Festival in Marshfield, MA on July 7, 2018
# TJ O'Neill, Stick Figure, KBong & Johnny Cosmic - "A Pirate Looks at 40" (Official Music Video)
# Stick Figure – "Above the Storm" (Official Music Video)
# Stick Figure – "Easy Runaway" (Official Lyric Video)
# Stick Figure - Breathe
# Stick Figure – "In This Love" (Official Music Video)
# Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio]

# %%
for i in range(5):
    # Scroll
    driver.execute_script(
    "window.scrollTo(0, document.documentElement.scrollHeight);"
    )
    
    #Wait for page to load
    time.sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
contents_div = soup.find('div', id='contents')
len(contents_div.find_all('a', id='video-title'))
# Out:
# 117

# %%
contents_div = soup.find('div', id='contents')

for title in contents_div.find_all('a', id='video-title'):
    print(title.text.strip())
# Out:
# Stick Figure – "World on Fire" (Full Album)
# Stick Figure – "Free Flow Sessions - June 2020"
# Keedron Bryant - I Just Wanna Live (Reggae Version)
# Stick Figure / Set in Stone (Full Album)
# Stick Figure – "Angels Above Me" (Official Music Video)
# Stick Figure – "Sound of the Sea" (Official Music Video)
# Stick Figure – "All for You" (Official Music Video)
# Weight of Sound
# Stick Figure - Weight of Sound
# Stick Figure – "Sentenced"
# Stick Figure – "Shine"
# Stick Figure - Heartland
# Stick Figure – "Fire on the Horizon" (Official Music Video)
# Stick Figure – "Once in a Lifetime"
# STICK FIGURE Full Concert at Levitate Music Festival in Marshfield, MA on July 7, 2018
# TJ O'Neill, Stick Figure, KBong & Johnny Cosmic - "A Pirate Looks at 40" (Official Music Video)
# Stick Figure – "Above the Storm" (Official Music Video)
# Stick Figure – "Easy Runaway" (Official Lyric Video)
# Stick Figure - Breathe
# Stick Figure – "In This Love" (Official Music Video)
# Stick Figure – "Choice is Yours" (feat. Slightly Stoopid) [Audio]
# Stick Figure – "Smiles on Faces" feat. KBong (Official Music Video)
# Stick Figure - Coming Home
# Stick Figure - Fire On The Horizon
# Stick Figure - Heartland
# Hawaii Song
# Stick Figure - Hawaii Song
# Stick Figure – "Summertime (feat. Citizen Cope)"
# Stick Figure – "Shine"
# Stick Figure – "Whiskey Sun (feat. TJ O'Neill)"
# Stick Figure - Just Another Dream
# Stick Figure – "Burn the Night"
# Stick Figure – "Sentenced"
# Stick Figure – "Shadow" (Official Music Video)
# Note Block Battle - Animation vs. Minecraft Shorts Ep 16 (Music by AaronGrooves)
# Stick Figure – "Out the Door"
# Stick Figure - Fight the Feeling [HD]
# Stick Figure – "Mind Block" (feat. Eric Rachmany of Rebelution)
# Stick Figure - Dreamland
# Stick Figure – "World on Fire (feat. Slightly Stoopid)"
# Note Blocks - Animation vs. Minecraft Shorts Ep. 5 (music by AaronGrooves)
# Stick Figure - World on Fire Remix Slightly Stoopid/Tribal Seeds/The Green/Common Kings/The Movement
# Animation vs. Minecraft Shorts 😊 STICK FIGURE Alan Becker Stickman vs Minecraft Shorts Episode 18
# Stick Figure Tournament
# Stick Figure - So Good
# Stick Figure - Hawaii Song (Music Video)
# Slightly Stoopid feat. Stick Figure - Too Late (Stick Figure Remix) [Official Music Video]
# Stick Figure at Levitate Music & Arts Festival 2019 - Livestream Replay (Entire Set)
# Stick Figure – "Smokin' Love" (feat. Collie Buddz)
# Stick Figure, Live in Las Vegas, December 31, 2019
# Texture Pack - Animation vs. Minecraft Shorts Ep 18
# Stick Figure - Smokin' Love, ft. Collie Buddz
# Stick Figure - Walk of Life (Music Video)
# Stick Figure – "Free Flow Sessions - June 2020"
# Stick Figure - Livin' It HD
# Stick Figure - Smoking Love (feat. Collie Buddz)
# Animation vs. Super Mario Bros (official)
# Reacting To World's Most Insane STICK FIGURE Animation
# Stick Figure – "Free Flow Van Sessions - May 2020"
# BeerX 2018 - Stick Figure Interview
# STICK FIGURE Live at California Roots Music & Arts Festival X   Day One   2019 05 24
# WORLD'S MOST INSANE STICK FIGHT ANIMATION!
# Stick Figure (feat. Wellzblock)
# I made a Stick Figure Animation Course!
# Stick Figure - "A Pirate Looks at 40" (Reggae Version) [with TJ O'Neill, KBong & Johnny Cosmic]
# Stick Figure – "Welcome to the Sun"
# Stick Figure - Shadow | Sugarshack #OneTake
# Mike Clark - "Sound Of The Sea" (Stick Figure vocal cover) *audio only*
# Stick Figure - Breathe
# Animator vs. Animation IV (original)
# Stick Figure - Once In A Lifetime (New Song 2019 / Lyrics)
# Stick Figure – "Free Flow Sessions - D-MO Dub"
# Stick Figure - Weight of Sound (LIVE)
# Stick Figure Live @ Red Rocks in Morrison, CO "Full Show w/ Encore Pro Shot HD" (05/04/2018)
# How to draw stick figures!
# The Movement ft. Stick Figure | "Siren" Live - California Roots 2019
# Stick Figure - Fallen Down | Reggae/Dub
# Right Here Right Now feat. Eric Rachmany and Stick Figure (Official Lyric) | IRATION
# Stick Figure - Cocoa De Rock (New Song 2019 / Lyrics)
# Weight of Sound (feat. TJ O'Neill)
# Stick Figure - Shelter
# Stick Figure – "Free Flow Sessions - April 2020"
# Stick Figure – Live rehearsal from Great Stone Studios - March 2019
# Redstone Academy - Animation vs. Minecraft Shorts Ep 15
# Stick Figure  Long Lost Way
# Stick Figure - Mind Block (Feat. Eric Rachmany) Lyrics
# Stick Figure - Thick & Thin | Reggae/Dub
# Stick Figure – "Fire on the Horizon" | REACTION
# Stick Figure - Breathe (Acoustic) - California Roots 2016
# Stick Figure - Rocky Road
# Stick Figure - Burn The Night (New Song 2019 / Lyrics)
# Right Here Right Now feat. Eric Rachmany and Stick Figure (Official Video) | IRATION
# Iration - Right Here Right Now (feat. Eric Rachmany & Stick Figure) Release 2020
# Stick Figure – "All for You"
# Stick Figure-World Is Waiting
# STICK FIGURE DEATH MAZES
# Stick Figure - Weight Of Sound (Lyrics)
# Stick Figure – Once in a Lifetime Summer Tour 2020 announced!
# Stick Figure - Easy Runaway (New Song 2018)
# Stick Figure - All My Love
# League of Legends | All Star 2013 Stick Figure Animation
# Stick figure - All for you 8D Audio
# Stick Figure – "Free Flow Sessions - October 2019"
# Stick Figure - Sound of the Sea
# STICK FIGURE - ANGELS ABOVE ME
# Counter-Strike - DE dust2 HD
# Stick Figure: Full Show - Breaking Band on AXS TV
# The Choice is your. Stick Figure with Lyrics
# Stick Figure vs. Barney
# Stick Figure – "Shadow"
# Stick Figure - Choice Is Yours (feat.Slightly Stoopid)
# Stick figure tutorial | Making a simple sword animation on phone with hand ( Flipaclip )
# Stick Figure - Free Flow Session - Joined (Longer)
# Stick Figure - Heartland (Music Video)
# Pepper - Warning (feat. Stick Figure) [OFFICIAL AUDIO]
# Stick Figure - The World is Waiting | Reggae Music
# Stick Figure – Red Rocks 2019 Recap

# %%
search_box = driver.find_element_by_xpath("//input[@id='search']")

#clear
search_box.clear()
#input new search
search_box.send_keys('Stick Figure')
# press enter
search_box.send_keys(Keys.RETURN)

# %%
filter_button = driver.find_element_by_xpath(
"//a[contains(@class, 'ytd-toggle-button')]"
)
filter_button.click()

# %%
first_author = driver.find_element_by_xpath(
"//ytd-video-renderer//ytd-channel-name//a"
)
first_author.text
# Out:
# 'Stick Figure'

# %%
driver.close()

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.opentable.com')
time.sleep(1)

# %%
from datetime import datetime, timedelta

# %%
today = datetime.today()
today_truncated = datetime(today.year, today.month, today.day)
res_date = (today + timedelta(days=3)).strftime('%a, %b, %d, %Y')
res_date
# Out:
# 'Fri, Jul, 10, 2020'

# %%
date_picker = driver.find_element_by_xpath('//div[@aria-label="Date selector"]')
date_picker.click()
time.sleep(1)

# %%
date_element = driver.find_element_by_xpath(f'//div[@aria-label="{res_date}"]')
date_element.click()
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-62-4ea803d02ef0> in <module>
# ----> 1 date_element = driver.find_element_by_xpath(f'//div[@aria-label="{res_date}"]')
#       2 date_element.click()
#       3 time.sleep(1)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@aria-label="Fri, Jul, 10, 2020"]"}
#   (Session info: chrome=83.0.4103.116)
