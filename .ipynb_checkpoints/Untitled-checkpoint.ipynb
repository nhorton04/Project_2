# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://www.boxofficemojo.com/year/2020/?ref_=bo_yl_table_1'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
table = soup.find_all('table')
df = pd.read_html(str(table))[0]
df
# Out:
#      Rank                                            Release Genre Budget  \
# 0       1                                  Bad Boys for Life     -      -
# 1       2                                               1917     -      -
# 2       3                                 Sonic the Hedgehog     -      -
# 3       4                            Jumanji: The Next Level     -      -
# 4       5      Star Wars: Episode IX - The Rise of Skywalker     -      -
# ..    ...                                                ...   ...    ...
# 262   263  I Do Not Care If We Go Down in History as Barb...     -      -
# 263   264                                           The Load     -      -
# 264   265                                       Asako I & II     -      -
# 265   266                                   Chained for Life     -      -
# 266   267                                 Shooting the Mafia     -      -
#
#     Running Time         Gross Theaters   Total Gross Release Date  \
# 0              -  $204,417,855     3775  $204,417,855       Jan 17
# 1              -  $157,901,466     3987  $159,227,644       Dec 25
# 2              -  $146,066,470     4198  $146,066,470       Feb 14
# 3              -  $124,736,710     4227  $316,831,246       Dec 13
# 4              -  $124,496,308     4406  $515,202,542       Dec 20
# ..           ...           ...      ...           ...          ...
# 262            -          $293        2       $11,307       Jul 19
# 263            -          $292        2       $28,410       Aug 30
# 264            -          $231        3       $25,559       May 17
# 265            -          $115        3       $17,431       Sep 13
# 266            -           $88        3       $10,881       Nov 22
#
#             Distributor  Estimated
# 0                     -      False
# 1    Universal Pictures      False
# 2    Paramount Pictures      False
# 3                     -      False
# 4                     -      False
# ..                  ...        ...
# 262  Big World Pictures      False
# 263    Grasshopper Film      False
# 264    Grasshopper Film      False
# 265  Kino International      False
# 266   Cohen Media Group      False
#
# [267 rows x 11 columns]

# %%
import dateutil.parser

def money_to_int(moneystring):
    if type(moneystring) != 'NoneType':
        moneystring = moneystring.replace('$', '').replace(',', '')
    else:
        moneystring = 'None'
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    if type(runtimestring) != 'NoneType':
        runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    if next_element:
        return next_element.text 
    else:
        return None

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['movie_title', 'domestic_total_gross',
               'runtime_minutes', 'rating', 'release_date', 'budget']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    #Get domestic gross
    try:
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                    .find_all('span', class_='money')[0]
                                    .text
                               )
    except:
        raw_domestic_total_gross = float("NaN")
    
    if type(raw_domestic_total_gross) == float or type(raw_domestic_total_gross) == 'NoneType':
        print('This is NaN')
        domestic_total_gross = float("NaN")
    else:
        domestic_total_gross = money_to_int(raw_domestic_total_gross)

    #Get runtime
    raw_runtime = get_movie_value(soup,'Running')
    if type(raw_runtime) != float and type(raw_runtime) != 'NoneType':
        runtime = runtime_to_minutes(raw_runtime)
    
    #Get rating
    rating = get_movie_value(soup,'MPAA')

    #Get release date
    if '-' in get_movie_value(soup, 'Release Date'):
        raw_release_date = get_movie_value(soup,'Release Date').split('-')[0]
    elif '(' in get_movie_value(soup, 'Release Date'):
        raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
    else:
        raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
    release_date = to_date(raw_release_date)
    


    # Get budget alt 
    raw_budget = get_movie_value(soup,'Budget')
    if raw_budget is None:
        budget = raw_budget
    else:
        budget = money_to_int(raw_budget)

    #Create movie dictionary and return
    movie_dict = dict(zip(headers,[title,
                                domestic_total_gross,
                                runtime,
                                rating, 
                                release_date,
                                budget]))

    return movie_dict

# %%
def get_movie_dict2(link):
    
    base_url = 'https://www.rottentomatoes.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['Movie Title', 'Tomatometer', 'Tomatometer Count',
               'Audience Score', 'Verified Ratings']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('(')[0]
    
    #Get ratings
    try:
        tomato_rating_div = soup.find('div', class_='mop-ratings-wrap__half')
        tomato_score = (tomato_rating_div
                        .find(class_='mop-ratings-wrap__percentage')
                        .text
                        .strip()
                        .split('%')[0]
                       )        
        
        audience_rating_div = soup.find('div', class_= 'mop-ratings-wrap__review-totals mop-ratings-wrap__review-totals--not-released')
        audience_score = (audience_rating_div
                            .find(class_='mop-ratings-wrap__text--small')
                            .text
                            .strip()
                           )
                               
    except:
        tomato_score, audience_score = None, None
        
    try:
        tomato_count_div = soup.find('div', class_='mop-ratings-wrap__review-totals')
        tomato_count = (tomato_rating_div.find('small', class_='mop-ratings-wrap__text--small')).text.strip()

        audience_count_div = soup.find('div', class_='mop-ratings-wrap__review-totals')
        audience_count = (audience_count_div.find('small', class_='mop-ratings-wrap__text--small')).text.strip()
    except:
        tomato_count, audience_count = None, None              


#     #Create movie dictionary and return
    movie_dict = dict(zip(headers, [
                            title, 
                            tomato_score, 
                            tomato_count,
                            audience_score, 
                            audience_count]))
    
    return movie_dict

# %%
tom_dicts = []

tomato_links = [
        'bad_boys_for_life',
        '1917_2019',
        'sonic_the_hedgehog_2020',
        'jumanji_the_next_level',
        'star_wars_the_rise_of_skywalker',
        'birds_of_prey_2020',
        'dolittle',
        'little_women_2019',
        'the_invisible_man_2020',
        'the_call_of_the_wild_2020',
        'onward',
        'knives_out',
        'frozen_ii',
        'spies_in_disguise',
        'the_gentlemen',
        'just_mercy',
        'parasite_2019',
        'fantasy_island_2020',
        'uncut_gems',
        'like_a_boss',
        'the_grudge_2020',
        'the_photograph_2020',
        'underwater_2020',
        'the_turning_2020',
        'gretel_and_hansel',
        'my_hero_academia_hero_heroes_rising',
        'bombshell_2019',
        'the_way_back_2020',
        'brahms_the_boy_ii',
        'jojo_rabbit',
        'impractical_jokers_the_movie',
        'ford_v_ferrari',
        'emma_2020',
        'bloodshot_2020',
        'i_still_believe',
        'downhill_2020',
        'weathering_with_you',
        'cats_2019',
        'the_hunt_2019',
        'the_rhythm_section',
        'a_beautiful_day_in_the_neighborhood',
        'richard_jewell',
        'portrait_of_a_lady_on_fire',
        '2020_oscar_nominated_shorts_animation',
        'queen_and_slim',
        '2020_oscar_nominated_shorts_live_action',
        'the_last_full_measure',
        'ip_man_4_the_finale',
        'the_wretched_2020',
        'joker_2019',
]

for link in tomato_links:
    tom_dicts.append(get_movie_dict2('/m/{}'.format(link)))
    
tom_dicts
# Out:
# [{'Movie Title': 'Bad Boys for Life ',
#   'Tomatometer': '77',
#   'Tomatometer Count': '254',
#   'Audience Score': 'Verified Ratings: 42,943',
#   'Verified Ratings': '254'},
#  {'Movie Title': '1917 ',
#   'Tomatometer': '89',
#   'Tomatometer Count': '432',
#   'Audience Score': 'Verified Ratings: 30,468',
#   'Verified Ratings': '432'},
#  {'Movie Title': 'Sonic the Hedgehog ',
#   'Tomatometer': '63',
#   'Tomatometer Count': '227',
#   'Audience Score': 'Verified Ratings: 19,411',
#   'Verified Ratings': '227'},
#  {'Movie Title': 'Jumanji: The Next Level ',
#   'Tomatometer': '72',
#   'Tomatometer Count': '236',
#   'Audience Score': 'Verified Ratings: 35,735',
#   'Verified Ratings': '236'},
#  {'Movie Title': 'Star Wars: The Rise of Skywalker ',
#   'Tomatometer': '51',
#   'Tomatometer Count': '486',
#   'Audience Score': 'Verified Ratings: 98,236',
#   'Verified Ratings': '486'},
#  {'Movie Title': 'Birds of Prey ',
#   'Tomatometer': '78',
#   'Tomatometer Count': '397',
#   'Audience Score': 'Verified Ratings: 15,708',
#   'Verified Ratings': '397'},
#  {'Movie Title': 'Dolittle ',
#   'Tomatometer': '14',
#   'Tomatometer Count': '223',
#   'Audience Score': 'Verified Ratings: 11,522',
#   'Verified Ratings': '223'},
#  {'Movie Title': 'Little Women ',
#   'Tomatometer': '94',
#   'Tomatometer Count': '397',
#   'Audience Score': 'Verified Ratings: 18,193',
#   'Verified Ratings': '397'},
#  {'Movie Title': 'The Invisible Man ',
#   'Tomatometer': '91',
#   'Tomatometer Count': '373',
#   'Audience Score': 'Verified Ratings: 11,898',
#   'Verified Ratings': '373'},
#  {'Movie Title': 'The Call of the Wild ',
#   'Tomatometer': '61',
#   'Tomatometer Count': '190',
#   'Audience Score': 'Verified Ratings: 9,360',
#   'Verified Ratings': '190'},
#  {'Movie Title': 'Onward ',
#   'Tomatometer': '88',
#   'Tomatometer Count': '314',
#   'Audience Score': 'Verified Ratings: 8,599',
#   'Verified Ratings': '314'},
#  {'Movie Title': 'Knives Out ',
#   'Tomatometer': '97',
#   'Tomatometer Count': '441',
#   'Audience Score': 'Verified Ratings: 33,827',
#   'Verified Ratings': '441'},
#  {'Movie Title': 'Frozen II ',
#   'Tomatometer': '77',
#   'Tomatometer Count': '317',
#   'Audience Score': 'Verified Ratings: 48,800',
#   'Verified Ratings': '317'},
#  {'Movie Title': 'Spies in Disguise ',
#   'Tomatometer': '75',
#   'Tomatometer Count': '118',
#   'Audience Score': 'Verified Ratings: 8,316',
#   'Verified Ratings': '118'},
#  {'Movie Title': 'The Gentlemen ',
#   'Tomatometer': '75',
#   'Tomatometer Count': '255',
#   'Audience Score': 'Verified Ratings: 9,630',
#   'Verified Ratings': '255'},
#  {'Movie Title': 'Just Mercy ',
#   'Tomatometer': '83',
#   'Tomatometer Count': '277',
#   'Audience Score': 'Verified Ratings: 11,818',
#   'Verified Ratings': '277'},
#  {'Movie Title': 'Parasite ',
#   'Tomatometer': '99',
#   'Tomatometer Count': '440',
#   'Audience Score': 'Verified Ratings: 7,273',
#   'Verified Ratings': '440'},
#  {'Movie Title': 'Fantasy Island ',
#   'Tomatometer': '8',
#   'Tomatometer Count': '102',
#   'Audience Score': 'Verified Ratings: 3,562',
#   'Verified Ratings': '102'},
#  {'Movie Title': 'Uncut Gems ',
#   'Tomatometer': '92',
#   'Tomatometer Count': '328',
#   'Audience Score': 'Verified Ratings: 12,111',
#   'Verified Ratings': '328'},
#  {'Movie Title': 'Like a Boss ',
#   'Tomatometer': '21',
#   'Tomatometer Count': '144',
#   'Audience Score': 'Verified Ratings: 3,422',
#   'Verified Ratings': '144'},
#  {'Movie Title': 'The Grudge ',
#   'Tomatometer': '20',
#   'Tomatometer Count': '119',
#   'Audience Score': 'Verified Ratings: 3,393',
#   'Verified Ratings': '119'},
#  {'Movie Title': 'The Photograph ',
#   'Tomatometer': '73',
#   'Tomatometer Count': '105',
#   'Audience Score': 'Verified Ratings: 7,289',
#   'Verified Ratings': '105'},
#  {'Movie Title': 'Underwater ',
#   'Tomatometer': '48',
#   'Tomatometer Count': '203',
#   'Audience Score': 'Verified Ratings: 2,857',
#   'Verified Ratings': '203'},
#  {'Movie Title': 'The Turning ',
#   'Tomatometer': '12',
#   'Tomatometer Count': '94',
#   'Audience Score': 'Verified Ratings: 2,189',
#   'Verified Ratings': '94'},
#  {'Movie Title': 'Gretel & Hansel ',
#   'Tomatometer': '65',
#   'Tomatometer Count': '94',
#   'Audience Score': 'Verified Ratings: 2,276',
#   'Verified Ratings': '94'},
#  {'Movie Title': 'Rotten Tomatoes: Movies - Rotten Tomatoes',
#   'Tomatometer': None,
#   'Tomatometer Count': None,
#   'Audience Score': None,
#   'Verified Ratings': None},
#  {'Movie Title': 'Bombshell ',
#   'Tomatometer': '70',
#   'Tomatometer Count': '310',
#   'Audience Score': 'Verified Ratings: 6,822',
#   'Verified Ratings': '310'},
#  {'Movie Title': 'The Way Back ',
#   'Tomatometer': '84',
#   'Tomatometer Count': '177',
#   'Audience Score': 'Verified Ratings: 2,690',
#   'Verified Ratings': '177'},
#  {'Movie Title': 'Brahms: The Boy II ',
#   'Tomatometer': '9',
#   'Tomatometer Count': '53',
#   'Audience Score': 'Verified Ratings: 1,304',
#   'Verified Ratings': '53'},
#  {'Movie Title': 'Jojo Rabbit ',
#   'Tomatometer': '80',
#   'Tomatometer Count': '402',
#   'Audience Score': 'Verified Ratings: 6,536',
#   'Verified Ratings': '402'},
#  {'Movie Title': 'Impractical Jokers: The Movie ',
#   'Tomatometer': '38',
#   'Tomatometer Count': '24',
#   'Audience Score': 'Verified Ratings: 2,273',
#   'Verified Ratings': '24'},
#  {'Movie Title': 'Ford v Ferrari ',
#   'Tomatometer': '92',
#   'Tomatometer Count': '329',
#   'Audience Score': 'Verified Ratings: 24,145',
#   'Verified Ratings': '329'},
#  {'Movie Title': 'Emma. ',
#   'Tomatometer': '87',
#   'Tomatometer Count': '227',
#   'Audience Score': 'Verified Ratings: 2,092',
#   'Verified Ratings': '227'},
#  {'Movie Title': 'Bloodshot ',
#   'Tomatometer': '30',
#   'Tomatometer Count': '155',
#   'Audience Score': 'Verified Ratings: 1,582',
#   'Verified Ratings': '155'},
#  {'Movie Title': 'I Still Believe ',
#   'Tomatometer': '51',
#   'Tomatometer Count': '43',
#   'Audience Score': 'Verified Ratings: 1,840',
#   'Verified Ratings': '43'},
#  {'Movie Title': 'Downhill ',
#   'Tomatometer': '38',
#   'Tomatometer Count': '195',
#   'Audience Score': 'Verified Ratings: 2,372',
#   'Verified Ratings': '195'},
#  {'Movie Title': 'Weathering with You ',
#   'Tomatometer': '91',
#   'Tomatometer Count': '87',
#   'Audience Score': 'Verified Ratings: 241',
#   'Verified Ratings': '87'},
#  {'Movie Title': 'Cats ',
#   'Tomatometer': '20',
#   'Tomatometer Count': '310',
#   'Audience Score': 'Verified Ratings: 6,963',
#   'Verified Ratings': '310'},
#  {'Movie Title': 'The Hunt ',
#   'Tomatometer': '56',
#   'Tomatometer Count': '230',
#   'Audience Score': 'Verified Ratings: 944',
#   'Verified Ratings': '230'},
#  {'Movie Title': 'The Rhythm Section ',
#   'Tomatometer': '29',
#   'Tomatometer Count': '167',
#   'Audience Score': 'Verified Ratings: 1,134',
#   'Verified Ratings': '167'},
#  {'Movie Title': 'A Beautiful Day in the Neighborhood ',
#   'Tomatometer': '96',
#   'Tomatometer Count': '344',
#   'Audience Score': 'Verified Ratings: 11,256',
#   'Verified Ratings': '344'},
#  {'Movie Title': 'Richard Jewell ',
#   'Tomatometer': '76',
#   'Tomatometer Count': '277',
#   'Audience Score': 'Verified Ratings: 6,115',
#   'Verified Ratings': '277'},
#  {'Movie Title': 'Portrait of a Lady on Fire ',
#   'Tomatometer': '98',
#   'Tomatometer Count': '292',
#   'Audience Score': 'Verified Ratings: 463',
#   'Verified Ratings': '292'},
#  {'Movie Title': '2020 Oscar Nominated Shorts - Animation ',
#   'Tomatometer': '95',
#   'Tomatometer Count': '22',
#   'Audience Score': 'User Ratings: Not yet available',
#   'Verified Ratings': '22'},
#  {'Movie Title': 'Queen & Slim ',
#   'Tomatometer': '82',
#   'Tomatometer Count': '207',
#   'Audience Score': 'Verified Ratings: 12,701',
#   'Verified Ratings': '207'},
#  {'Movie Title': '2020 Oscar Nominated Shorts - Live Action ',
#   'Tomatometer': '89',
#   'Tomatometer Count': '18',
#   'Audience Score': 'User Ratings: 13',
#   'Verified Ratings': '18'},
#  {'Movie Title': 'The Last Full Measure ',
#   'Tomatometer': '59',
#   'Tomatometer Count': '69',
#   'Audience Score': 'Verified Ratings: 1,106',
#   'Verified Ratings': '69'},
#  {'Movie Title': 'Ip Man 4: The Finale ',
#   'Tomatometer': '90',
#   'Tomatometer Count': '30',
#   'Audience Score': 'Verified Ratings: 826',
#   'Verified Ratings': '30'},
#  {'Movie Title': 'The Wretched ',
#   'Tomatometer': '74',
#   'Tomatometer Count': '97',
#   'Audience Score': 'User Ratings: 213',
#   'Verified Ratings': '97'},
#  {'Movie Title': 'Joker ',
#   'Tomatometer': '68',
#   'Tomatometer Count': '563',
#   'Audience Score': 'Verified Ratings: 66,292',
#   'Verified Ratings': '563'}]

# %%
mojo_links = [ 
        'rl1182631425',
        'rl2969994753',
        'rl4244997633',
        'rl755467777',
        'rl3305145857',
        'rl3640886785',
        'rl2164295169',
        'rl218596865',
        'rl50628097',
        'rl2533524993',
        'rl3433267713',
        'rl3204875777',
        'rl2424210945',
        'rl1333691905',
        'rl3473442305',
        'rl419792385',
        'rl1258849793',
        'rl1611040257',
        'rl3825763841',
        'rl4278486529',
        'rl1745126913',
        'rl1655931393',
        'rl302548481',
        'rl3020195329',
        'rl3842541057',
        'rl867926529',
        'rl2550760961',
        'rl4127819265',
        'rl2567538177',
        'rl2030601729',
        'rl2998501889',
        'rl990348801',
        'rl3221784065',
        'rl235374081',
        'rl1628014081',
        'rl2611249665',
        'rl3669066241',
        'rl2684847617',
        'rl1459979777',
        'rl3775038977',
        'rl2651096577',
        'rl2903213569',
        'rl1325958657',
        'rl615875073'
        'rl50824705',
        'rl537298433',
        'rl1617987073',
        'rl1386316289',
        'rl716997121',
        'rl252151297'
        ]

dicts = []

for link in mojo_links:
    dicts.append(get_movie_dict('/release/{}/'.format(link)))

dicts
# Out:
# [{'movie_title': 'Bad Boys for Life',
#   'domestic_total_gross': 204417855,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 17, 0, 0),
#   'budget': 90000000},
#  {'movie_title': '1917',
#   'domestic_total_gross': 159227644,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 95000000},
#  {'movie_title': 'Sonic the Hedgehog',
#   'domestic_total_gross': 146066470,
#   'runtime_minutes': 99,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 85000000},
#  {'movie_title': 'Jumanji: The Next Level',
#   'domestic_total_gross': 316831246,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 125000000},
#  {'movie_title': 'Star Wars: Episode IX',
#   'domestic_total_gross': 515202542,
#   'runtime_minutes': 142,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0),
#   'budget': 275000000},
#  {'movie_title': 'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#   'domestic_total_gross': 84158461,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 7, 0, 0),
#   'budget': 84500000},
#  {'movie_title': 'Dolittle',
#   'domestic_total_gross': 77047065,
#   'runtime_minutes': 101,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 1, 17, 0, 0),
#   'budget': 175000000},
#  {'movie_title': 'Little Women',
#   'domestic_total_gross': 108101214,
#   'runtime_minutes': 135,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 40000000},
#  {'movie_title': 'The Invisible Man',
#   'domestic_total_gross': 64914050,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 28, 0, 0),
#   'budget': 7000000},
#  {'movie_title': 'The Call of the Wild',
#   'domestic_total_gross': 62342368,
#   'runtime_minutes': 100,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 135000000},
#  {'movie_title': 'Onward',
#   'domestic_total_gross': 61555145,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 3, 6, 0, 0),
#   'budget': None},
#  {'movie_title': 'Knives Out',
#   'domestic_total_gross': 165363234,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 11, 27, 0, 0),
#   'budget': 40000000},
#  {'movie_title': 'Frozen II',
#   'domestic_total_gross': 477373578,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0),
#   'budget': 150000000},
#  {'movie_title': 'Spies in Disguise',
#   'domestic_total_gross': 66757013,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 100000000},
#  {'movie_title': 'The Gentlemen',
#   'domestic_total_gross': 36296853,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': 22000000},
#  {'movie_title': 'Just Mercy',
#   'domestic_total_gross': 36001502,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 25000000},
#  {'movie_title': 'Parasite',
#   'domestic_total_gross': 53369749,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 10, 11, 0, 0),
#   'budget': 11400000},
#  {'movie_title': 'Fantasy Island',
#   'domestic_total_gross': 26441782,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 7000000},
#  {'movie_title': 'Uncut Gems',
#   'domestic_total_gross': 50023780,
#   'runtime_minutes': 135,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 19000000},
#  {'movie_title': 'Like a Boss',
#   'domestic_total_gross': 22169514,
#   'runtime_minutes': 83,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 10, 0, 0),
#   'budget': 29000000},
#  {'movie_title': 'The Grudge',
#   'domestic_total_gross': 21221803,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 3, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'The Photograph',
#   'domestic_total_gross': 20578185,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 16000000},
#  {'movie_title': 'Underwater',
#   'domestic_total_gross': 17291078,
#   'runtime_minutes': 95,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 10, 0, 0),
#   'budget': None},
#  {'movie_title': 'The Turning',
#   'domestic_total_gross': 15472775,
#   'runtime_minutes': 94,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'Gretel & Hansel',
#   'domestic_total_gross': 15347654,
#   'runtime_minutes': 87,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 31, 0, 0),
#   'budget': None},
#  {'movie_title': 'My Hero Academia: Heroes Rising',
#   'domestic_total_gross': 13304000,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 26, 0, 0),
#   'budget': None},
#  {'movie_title': 'Bombshell',
#   'domestic_total_gross': 31762808,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 32000000},
#  {'movie_title': 'The Way Back',
#   'domestic_total_gross': 13590514,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 3, 6, 0, 0),
#   'budget': None},
#  {'movie_title': 'Brahms: The Boy II',
#   'domestic_total_gross': 12611536,
#   'runtime_minutes': 86,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'Jojo Rabbit',
#   'domestic_total_gross': 33370906,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'Impractical Jokers: The Movie',
#   'domestic_total_gross': 10691091,
#   'runtime_minutes': 92,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 3000000},
#  {'movie_title': 'Ford v Ferrari',
#   'domestic_total_gross': 117624357,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 11, 15, 0, 0),
#   'budget': 97600000},
#  {'movie_title': 'Emma.',
#   'domestic_total_gross': 10055355,
#   'runtime_minutes': 124,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'Bloodshot',
#   'domestic_total_gross': 10021787,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 45000000},
#  {'movie_title': 'I Still Believe',
#   'domestic_total_gross': 9868521,
#   'runtime_minutes': 116,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 12000000},
#  {'movie_title': 'Downhill',
#   'domestic_total_gross': 8287061,
#   'runtime_minutes': 86,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': None},
#  {'movie_title': 'Weathering with You',
#   'domestic_total_gross': 7798743,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 15, 0, 0),
#   'budget': None},
#  {'movie_title': 'Cats',
#   'domestic_total_gross': 27166770,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0),
#   'budget': 95000000},
#  {'movie_title': 'The Hunt',
#   'domestic_total_gross': 5812500,
#   'runtime_minutes': 90,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'The Rhythm Section',
#   'domestic_total_gross': 5437971,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 31, 0, 0),
#   'budget': 50000000},
#  {'movie_title': 'A Beautiful Day in the Neighborhood',
#   'domestic_total_gross': 61704055,
#   'runtime_minutes': 109,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0),
#   'budget': 25000000},
#  {'movie_title': 'Richard Jewell',
#   'domestic_total_gross': 22345542,
#   'runtime_minutes': 131,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 45000000},
#  {'movie_title': 'Portrait of a Lady on Fire',
#   'domestic_total_gross': 3759854,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 6, 0, 0),
#   'budget': None},
#  {'movie_title': '2020 Oscar Nominated Short Films',
#   'domestic_total_gross': 3306611,
#   'runtime_minutes': 153,
#   'rating': None,
#   'release_date': datetime.datetime(2020, 1, 31, 0, 0),
#   'budget': None},
#  {'movie_title': 'Las Pildoras De Mi Novio',
#   'domestic_total_gross': 2971116,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': None},
#  {'movie_title': 'The Last Full Measure',
#   'domestic_total_gross': 2949212,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': None},
#  {'movie_title': 'Ip Man 4: The Finale',
#   'domestic_total_gross': 3956031,
#   'runtime_minutes': 107,
#   'rating': None,
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': None},
#  {'movie_title': 'The Wretched',
#   'domestic_total_gross': 1698568,
#   'runtime_minutes': 95,
#   'rating': None,
#   'release_date': datetime.datetime(2020, 5, 1, 0, 0),
#   'budget': None},
#  {'movie_title': 'Joker',
#   'domestic_total_gross': 335451311,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 10, 4, 0, 0),
#   'budget': 55000000}]
