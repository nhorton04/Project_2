# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
import re
import seaborn as sns

# %% [markdown]
# Request Info

# %%
url = 'https://www.boxofficemojo.com/title/tt7286456/'
response = requests.get(url)
page = response.text

soup = BeautifulSoup(page, 'html5lib')

# %% [markdown]
# Money to int, runtime to minutes, date to datestring function

# %%
import dateutil.parser

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    print(type(runtimestring))
    if type(runtimestring) != 'NoneType':
        runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['movie_title', 'domestic_total_gross',
               'runtime_minutes', 'rating', 'release_date', 'budget']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    #Get domestic gross
    try:
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                    .find_all('span', class_='money')[0]
                                    .text
                               )
    except:
        raw_domestic_total_gross = float("NaN")
    
    if type(raw_domestic_total_gross) == float or type(raw_domestic_total_gross) == 'NoneType':
        print('This is a NaN')
        domestic_total_gross = float("NaN")
    else:
        domestic_total_gross = money_to_int(raw_domestic_total_gross)

    #Get runtime
    raw_runtime = get_movie_value(soup,'Running')
    if type(raw_runtime) != float and type(raw_runtime) != 'NoneType':
        runtime = runtime_to_minutes(raw_runtime)
    
    #Get rating
    rating = get_movie_value(soup,'MPAA')

    #Get release date
    if '-' in get_movie_value(soup, 'Release Date'):
        raw_release_date = get_movie_value(soup,'Release Date').split('-')[0]
    elif '(' in get_movie_value(soup, 'Release Date'):
        raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
    else:
        raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
    release_date = to_date(raw_release_date)
    
    # Get budget
    budget = soup.find(class_='mojo-summary-values')
    answer = []
    money = budget.find_all(class_='money')
    for m in money:
        answer.append(m) 
    budget = answer[-1].text
    if type(budget) != float and type(budget) != 'NoneType':
        budget = money_to_int(budget)
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers,[title,
                                domestic_total_gross,
                                runtime,
                                rating, 
                                release_date,
                                budget]))

    return movie_dict

# %%
links = [ 
        'rl1182631425',
        'rl2969994753',
        'rl4244997633',
        'rl755467777',
        'rl3305145857',
        'rl3640886785',
        'rl2164295169',
        'rl218596865',
        'rl50628097',
        'rl2533524993',
        'rl3433267713',
        'rl3204875777',
        'rl2424210945',
        'rl1333691905',
        'rl3473442305',
        'rl419792385',
        'rl1258849793',
        'rl1611040257',
        'rl3825763841',
        'rl4278486529',
        'rl1745126913',
        'rl1655931393',
        'rl302548481',
        'rl3020195329',
        'rl3842541057',
        'rl867926529',
        'rl2550760961',
        'rl4127819265',
        'rl2567538177',
        'rl2030601729',
        'rl2998501889',
        'rl990348801',
        'rl3221784065',
        'rl235374081',
        'rl1628014081',
        'rl2611249665',
        'rl3669066241',
        'rl2684847617',
        'rl1459979777',
        'rl3775038977',
        'rl2651096577',
        'rl2903213569',
        'rl1325958657',
        'rl50824705',
        'rl537298433',
        'rl1617987073',
        'rl1386316289',
        'rl716997121',
        'rl252151297'
        ]

dicts = []

for link in links:
    dicts.append(get_movie_dict('/release/{}/'.format(link)))

dicts
# Out:
# Bad Boys for Life
# <class 'str'>
# 1917
# <class 'str'>
# Sonic the Hedgehog
# <class 'str'>
# Jumanji: The Next Level
# <class 'str'>
# Star Wars: Episode IX
# <class 'str'>
# Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn
# <class 'str'>
# Dolittle
# <class 'str'>
# Little Women
# <class 'str'>
# The Invisible Man
# <class 'str'>
# The Call of the Wild
# <class 'str'>
# Onward
# <class 'str'>
# Knives Out
# <class 'str'>
# Frozen II
# <class 'str'>
# Spies in Disguise
# <class 'str'>
# The Gentlemen
# <class 'str'>
# Just Mercy
# <class 'str'>
# Parasite
# <class 'str'>
# Fantasy Island
# <class 'str'>
# Uncut Gems
# <class 'str'>
# Like a Boss
# <class 'str'>
# The Grudge
# <class 'str'>
# The Photograph
# <class 'str'>
# Underwater
# <class 'str'>
# The Turning
# <class 'str'>
# Gretel & Hansel
# <class 'str'>
# My Hero Academia: Heroes Rising
# <class 'str'>
# Bombshell
# <class 'str'>
# The Way Back
# <class 'str'>
# Brahms: The Boy II
# <class 'str'>
# Jojo Rabbit
# <class 'str'>
# Impractical Jokers: The Movie
# <class 'str'>
# Ford v Ferrari
# <class 'str'>
# Emma.
# <class 'str'>
# Bloodshot
# <class 'str'>
# I Still Believe
# <class 'str'>
# Downhill
# <class 'str'>
# Weathering with You
# <class 'str'>
# Cats
# <class 'str'>
# The Hunt
# <class 'str'>
# The Rhythm Section
# <class 'str'>
# A Beautiful Day in the Neighborhood
# <class 'str'>
# Richard Jewell
# <class 'str'>
# Portrait of a Lady on Fire
# <class 'str'>
# Queen & Slim
# <class 'str'>
# Las Pildoras De Mi Novio
# <class 'str'>
# The Last Full Measure
# <class 'str'>
# Ip Man 4: The Finale
# <class 'str'>
# The Wretched
# <class 'str'>
# Joker
# <class 'str'>
# [{'movie_title': 'Bad Boys for Life',
#   'domestic_total_gross': 204417855,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 17, 0, 0),
#   'budget': 90000000},
#  {'movie_title': '1917',
#   'domestic_total_gross': 159227644,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 95000000},
#  {'movie_title': 'Sonic the Hedgehog',
#   'domestic_total_gross': 146066470,
#   'runtime_minutes': 99,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 85000000},
#  {'movie_title': 'Jumanji: The Next Level',
#   'domestic_total_gross': 316831246,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 125000000},
#  {'movie_title': 'Star Wars: Episode IX',
#   'domestic_total_gross': 515202542,
#   'runtime_minutes': 142,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0),
#   'budget': 275000000},
#  {'movie_title': 'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#   'domestic_total_gross': 84158461,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 7, 0, 0),
#   'budget': 84500000},
#  {'movie_title': 'Dolittle',
#   'domestic_total_gross': 77047065,
#   'runtime_minutes': 101,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 1, 17, 0, 0),
#   'budget': 175000000},
#  {'movie_title': 'Little Women',
#   'domestic_total_gross': 108101214,
#   'runtime_minutes': 135,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 40000000},
#  {'movie_title': 'The Invisible Man',
#   'domestic_total_gross': 64914050,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 28, 0, 0),
#   'budget': 7000000},
#  {'movie_title': 'The Call of the Wild',
#   'domestic_total_gross': 62342368,
#   'runtime_minutes': 100,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 135000000},
#  {'movie_title': 'Onward',
#   'domestic_total_gross': 61555145,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 3, 6, 0, 0),
#   'budget': 39119861},
#  {'movie_title': 'Knives Out',
#   'domestic_total_gross': 165363234,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 11, 27, 0, 0),
#   'budget': 40000000},
#  {'movie_title': 'Frozen II',
#   'domestic_total_gross': 477373578,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0),
#   'budget': 150000000},
#  {'movie_title': 'Spies in Disguise',
#   'domestic_total_gross': 66757013,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 100000000},
#  {'movie_title': 'The Gentlemen',
#   'domestic_total_gross': 36296853,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': 22000000},
#  {'movie_title': 'Just Mercy',
#   'domestic_total_gross': 36001502,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 25000000},
#  {'movie_title': 'Parasite',
#   'domestic_total_gross': 53369749,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 10, 11, 0, 0),
#   'budget': 11400000},
#  {'movie_title': 'Fantasy Island',
#   'domestic_total_gross': 26441782,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 7000000},
#  {'movie_title': 'Uncut Gems',
#   'domestic_total_gross': 50023780,
#   'runtime_minutes': 135,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 19000000},
#  {'movie_title': 'Like a Boss',
#   'domestic_total_gross': 22169514,
#   'runtime_minutes': 83,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 10, 0, 0),
#   'budget': 29000000},
#  {'movie_title': 'The Grudge',
#   'domestic_total_gross': 21221803,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 3, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'The Photograph',
#   'domestic_total_gross': 20578185,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 16000000},
#  {'movie_title': 'Underwater',
#   'domestic_total_gross': 17291078,
#   'runtime_minutes': 95,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 10, 0, 0),
#   'budget': 7008297},
#  {'movie_title': 'The Turning',
#   'domestic_total_gross': 15472775,
#   'runtime_minutes': 94,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'Gretel & Hansel',
#   'domestic_total_gross': 15347654,
#   'runtime_minutes': 87,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 31, 0, 0),
#   'budget': 6154007},
#  {'movie_title': 'My Hero Academia: Heroes Rising',
#   'domestic_total_gross': 13304000,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 26, 0, 0),
#   'budget': 5891252},
#  {'movie_title': 'Bombshell',
#   'domestic_total_gross': 31762808,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 32000000},
#  {'movie_title': 'The Way Back',
#   'domestic_total_gross': 13590514,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 3, 6, 0, 0),
#   'budget': 8170315},
#  {'movie_title': 'Brahms: The Boy II',
#   'domestic_total_gross': 12611536,
#   'runtime_minutes': 86,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'Jojo Rabbit',
#   'domestic_total_gross': 33370906,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'Impractical Jokers: The Movie',
#   'domestic_total_gross': 10691091,
#   'runtime_minutes': 92,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 3000000},
#  {'movie_title': 'Ford v Ferrari',
#   'domestic_total_gross': 117624357,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2019, 11, 15, 0, 0),
#   'budget': 97600000},
#  {'movie_title': 'Emma.',
#   'domestic_total_gross': 10055355,
#   'runtime_minutes': 124,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 10000000},
#  {'movie_title': 'Bloodshot',
#   'domestic_total_gross': 10021787,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 45000000},
#  {'movie_title': 'I Still Believe',
#   'domestic_total_gross': 9868521,
#   'runtime_minutes': 116,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 12000000},
#  {'movie_title': 'Downhill',
#   'domestic_total_gross': 8287061,
#   'runtime_minutes': 86,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 14, 0, 0),
#   'budget': 4622018},
#  {'movie_title': 'Weathering with You',
#   'domestic_total_gross': 7798743,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_date': datetime.datetime(2020, 1, 15, 0, 0),
#   'budget': 1808533},
#  {'movie_title': 'Cats',
#   'domestic_total_gross': 27166770,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0),
#   'budget': 95000000},
#  {'movie_title': 'The Hunt',
#   'domestic_total_gross': 5812500,
#   'runtime_minutes': 90,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 3, 13, 0, 0),
#   'budget': 14000000},
#  {'movie_title': 'The Rhythm Section',
#   'domestic_total_gross': 5437971,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 31, 0, 0),
#   'budget': 50000000},
#  {'movie_title': 'A Beautiful Day in the Neighborhood',
#   'domestic_total_gross': 61704055,
#   'runtime_minutes': 109,
#   'rating': 'PG',
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0),
#   'budget': 25000000},
#  {'movie_title': 'Richard Jewell',
#   'domestic_total_gross': 22345542,
#   'runtime_minutes': 131,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0),
#   'budget': 45000000},
#  {'movie_title': 'Portrait of a Lady on Fire',
#   'domestic_total_gross': 3759854,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 12, 6, 0, 0),
#   'budget': 67344},
#  {'movie_title': 'Queen & Slim',
#   'domestic_total_gross': 43808310,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 11, 27, 0, 0),
#   'budget': 18000000},
#  {'movie_title': 'Las Pildoras De Mi Novio',
#   'domestic_total_gross': 2971116,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 2, 21, 0, 0),
#   'budget': 1396140},
#  {'movie_title': 'The Last Full Measure',
#   'domestic_total_gross': 2949212,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_date': datetime.datetime(2020, 1, 24, 0, 0),
#   'budget': 1058019},
#  {'movie_title': 'Ip Man 4: The Finale',
#   'domestic_total_gross': 3956031,
#   'runtime_minutes': 107,
#   'rating': None,
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0),
#   'budget': 737718},
#  {'movie_title': 'The Wretched',
#   'domestic_total_gross': 1695031,
#   'runtime_minutes': 95,
#   'rating': None,
#   'release_date': datetime.datetime(2020, 5, 1, 0, 0),
#   'budget': 65908},
#  {'movie_title': 'Joker',
#   'domestic_total_gross': 335451311,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_date': datetime.datetime(2019, 10, 4, 0, 0),
#   'budget': 55000000}]

# %%
# df = pd.DataFrame.from_dict({'title': movies['movie_title'], 
#                              'domestic_total_gross': movies['domestic_total_gross'],
#                              'runtime_minutes': movies['runtime_minutes'],
#                              'rating': movies['rating'],
#                              'release_date': movies['release_date'],
#                              'budget': movies['budget']
#                             }, index=[0])

df = pd.DataFrame(dicts)
# df = (df.sort_values(by=['rank'])
#                     .reset_index()
#                     .drop(columns = ['index']))
df
# df.columns = df.iloc[0]
df.columns = ['Movie Title', 'Domestic Gross', 'Runtime (mins)', 'Rating', 'Release Date', 'Budget']
# df.columns=['movie_title', 'domestic_total_gross',
#                'runtime_minutes', 'rating', 'release_date', 'budget']
df
# Out:
#                                           Movie Title  Domestic Gross  \
# 0                                   Bad Boys for Life       204417855
# 1                                                1917       159227644
# 2                                  Sonic the Hedgehog       146066470
# 3                             Jumanji: The Next Level       316831246
# 4                               Star Wars: Episode IX       515202542
# 5   Birds of Prey: And the Fantabulous Emancipatio...        84158461
# 6                                            Dolittle        77047065
# 7                                        Little Women       108101214
# 8                                   The Invisible Man        64914050
# 9                                The Call of the Wild        62342368
# 10                                             Onward        61555145
# 11                                         Knives Out       165363234
# 12                                          Frozen II       477373578
# 13                                  Spies in Disguise        66757013
# 14                                      The Gentlemen        36296853
# 15                                         Just Mercy        36001502
# 16                                           Parasite        53369749
# 17                                     Fantasy Island        26441782
# 18                                         Uncut Gems        50023780
# 19                                        Like a Boss        22169514
# 20                                         The Grudge        21221803
# 21                                     The Photograph        20578185
# 22                                         Underwater        17291078
# 23                                        The Turning        15472775
# 24                                    Gretel & Hansel        15347654
# 25                    My Hero Academia: Heroes Rising        13304000
# 26                                          Bombshell        31762808
# 27                                       The Way Back        13590514
# 28                                 Brahms: The Boy II        12611536
# 29                                        Jojo Rabbit        33370906
# 30                      Impractical Jokers: The Movie        10691091
# 31                                     Ford v Ferrari       117624357
# 32                                              Emma.        10055355
# 33                                          Bloodshot        10021787
# 34                                    I Still Believe         9868521
# 35                                           Downhill         8287061
# 36                                Weathering with You         7798743
# 37                                               Cats        27166770
# 38                                           The Hunt         5812500
# 39                                 The Rhythm Section         5437971
# 40                A Beautiful Day in the Neighborhood        61704055
# 41                                     Richard Jewell        22345542
# 42                         Portrait of a Lady on Fire         3759854
# 43                                       Queen & Slim        43808310
# 44                           Las Pildoras De Mi Novio         2971116
# 45                              The Last Full Measure         2949212
# 46                               Ip Man 4: The Finale         3956031
# 47                                       The Wretched         1695031
# 48                                              Joker       335451311
#
#     Runtime (mins) Rating Release Date     Budget
# 0              124      R   2020-01-17   90000000
# 1              119      R   2019-12-25   95000000
# 2               99     PG   2020-02-14   85000000
# 3              123  PG-13   2019-12-13  125000000
# 4              142  PG-13   2019-12-20  275000000
# 5              109      R   2020-02-07   84500000
# 6              101     PG   2020-01-17  175000000
# 7              135     PG   2019-12-25   40000000
# 8              124      R   2020-02-28    7000000
# 9              100     PG   2020-02-21  135000000
# 10             102     PG   2020-03-06   39119861
# 11             130  PG-13   2019-11-27   40000000
# 12             103     PG   2019-11-22  150000000
# 13             102     PG   2019-12-25  100000000
# 14             113      R   2020-01-24   22000000
# 15             137  PG-13   2019-12-25   25000000
# 16             132      R   2019-10-11   11400000
# 17             109  PG-13   2020-02-14    7000000
# 18             135      R   2019-12-13   19000000
# 19              83      R   2020-01-10   29000000
# 20              94      R   2020-01-03   10000000
# 21             106  PG-13   2020-02-14   16000000
# 22              95  PG-13   2020-01-10    7008297
# 23              94  PG-13   2020-01-24   14000000
# 24              87  PG-13   2020-01-31    6154007
# 25             104  PG-13   2020-02-26    5891252
# 26             109      R   2019-12-13   32000000
# 27             108      R   2020-03-06    8170315
# 28              86  PG-13   2020-02-21   10000000
# 29             108  PG-13   2019-10-18   14000000
# 30              92  PG-13   2020-02-21    3000000
# 31             152  PG-13   2019-11-15   97600000
# 32             124     PG   2020-02-21   10000000
# 33             109  PG-13   2020-03-13   45000000
# 34             116     PG   2020-03-13   12000000
# 35              86      R   2020-02-14    4622018
# 36             112  PG-13   2020-01-15    1808533
# 37             110     PG   2019-12-20   95000000
# 38              90      R   2020-03-13   14000000
# 39             109      R   2020-01-31   50000000
# 40             109     PG   2019-11-22   25000000
# 41             131      R   2019-12-13   45000000
# 42             122      R   2019-12-06      67344
# 43             132      R   2019-11-27   18000000
# 44             100      R   2020-02-21    1396140
# 45             116      R   2020-01-24    1058019
# 46             107   None   2019-12-25     737718
# 47              95   None   2020-05-01      65908
# 48             122      R   2019-10-04   55000000

# %%
# g_movies = pd.DataFrame(movies)
# g_movies.columns(['movie_title', 'domestic_total_gross',
#                'runtime_minutes', 'rating', 'release_date', 'budget'])
# g_movies.head()

# %%
rating_one_hot = pd.get_dummies(df['Rating'])
frames = [df, rating_one_hot]

df.merge(rating_one_hot, left_index=True, right_index=True)
# Out:
#                                           Movie Title  Domestic Gross  \
# 0                                   Bad Boys for Life       204417855
# 1                                                1917       159227644
# 2                                  Sonic the Hedgehog       146066470
# 3                             Jumanji: The Next Level       316831246
# 4                               Star Wars: Episode IX       515202542
# 5   Birds of Prey: And the Fantabulous Emancipatio...        84158461
# 6                                            Dolittle        77047065
# 7                                        Little Women       108101214
# 8                                   The Invisible Man        64914050
# 9                                The Call of the Wild        62342368
# 10                                             Onward        61555145
# 11                                         Knives Out       165363234
# 12                                          Frozen II       477373578
# 13                                  Spies in Disguise        66757013
# 14                                      The Gentlemen        36296853
# 15                                         Just Mercy        36001502
# 16                                           Parasite        53369749
# 17                                     Fantasy Island        26441782
# 18                                         Uncut Gems        50023780
# 19                                        Like a Boss        22169514
# 20                                         The Grudge        21221803
# 21                                     The Photograph        20578185
# 22                                         Underwater        17291078
# 23                                        The Turning        15472775
# 24                                    Gretel & Hansel        15347654
# 25                    My Hero Academia: Heroes Rising        13304000
# 26                                          Bombshell        31762808
# 27                                       The Way Back        13590514
# 28                                 Brahms: The Boy II        12611536
# 29                                        Jojo Rabbit        33370906
# 30                      Impractical Jokers: The Movie        10691091
# 31                                     Ford v Ferrari       117624357
# 32                                              Emma.        10055355
# 33                                          Bloodshot        10021787
# 34                                    I Still Believe         9868521
# 35                                           Downhill         8287061
# 36                                Weathering with You         7798743
# 37                                               Cats        27166770
# 38                                           The Hunt         5812500
# 39                                 The Rhythm Section         5437971
# 40                A Beautiful Day in the Neighborhood        61704055
# 41                                     Richard Jewell        22345542
# 42                         Portrait of a Lady on Fire         3759854
# 43                                       Queen & Slim        43808310
# 44                           Las Pildoras De Mi Novio         2971116
# 45                              The Last Full Measure         2949212
# 46                               Ip Man 4: The Finale         3956031
# 47                                       The Wretched         1695031
# 48                                              Joker       335451311
#
#     Runtime (mins) Rating Release Date     Budget  PG  PG-13  R
# 0              124      R   2020-01-17   90000000   0      0  1
# 1              119      R   2019-12-25   95000000   0      0  1
# 2               99     PG   2020-02-14   85000000   1      0  0
# 3              123  PG-13   2019-12-13  125000000   0      1  0
# 4              142  PG-13   2019-12-20  275000000   0      1  0
# 5              109      R   2020-02-07   84500000   0      0  1
# 6              101     PG   2020-01-17  175000000   1      0  0
# 7              135     PG   2019-12-25   40000000   1      0  0
# 8              124      R   2020-02-28    7000000   0      0  1
# 9              100     PG   2020-02-21  135000000   1      0  0
# 10             102     PG   2020-03-06   39119861   1      0  0
# 11             130  PG-13   2019-11-27   40000000   0      1  0
# 12             103     PG   2019-11-22  150000000   1      0  0
# 13             102     PG   2019-12-25  100000000   1      0  0
# 14             113      R   2020-01-24   22000000   0      0  1
# 15             137  PG-13   2019-12-25   25000000   0      1  0
# 16             132      R   2019-10-11   11400000   0      0  1
# 17             109  PG-13   2020-02-14    7000000   0      1  0
# 18             135      R   2019-12-13   19000000   0      0  1
# 19              83      R   2020-01-10   29000000   0      0  1
# 20              94      R   2020-01-03   10000000   0      0  1
# 21             106  PG-13   2020-02-14   16000000   0      1  0
# 22              95  PG-13   2020-01-10    7008297   0      1  0
# 23              94  PG-13   2020-01-24   14000000   0      1  0
# 24              87  PG-13   2020-01-31    6154007   0      1  0
# 25             104  PG-13   2020-02-26    5891252   0      1  0
# 26             109      R   2019-12-13   32000000   0      0  1
# 27             108      R   2020-03-06    8170315   0      0  1
# 28              86  PG-13   2020-02-21   10000000   0      1  0
# 29             108  PG-13   2019-10-18   14000000   0      1  0
# 30              92  PG-13   2020-02-21    3000000   0      1  0
# 31             152  PG-13   2019-11-15   97600000   0      1  0
# 32             124     PG   2020-02-21   10000000   1      0  0
# 33             109  PG-13   2020-03-13   45000000   0      1  0
# 34             116     PG   2020-03-13   12000000   1      0  0
# 35              86      R   2020-02-14    4622018   0      0  1
# 36             112  PG-13   2020-01-15    1808533   0      1  0
# 37             110     PG   2019-12-20   95000000   1      0  0
# 38              90      R   2020-03-13   14000000   0      0  1
# 39             109      R   2020-01-31   50000000   0      0  1
# 40             109     PG   2019-11-22   25000000   1      0  0
# 41             131      R   2019-12-13   45000000   0      0  1
# 42             122      R   2019-12-06      67344   0      0  1
# 43             132      R   2019-11-27   18000000   0      0  1
# 44             100      R   2020-02-21    1396140   0      0  1
# 45             116      R   2020-01-24    1058019   0      0  1
# 46             107   None   2019-12-25     737718   0      0  0
# 47              95   None   2020-05-01      65908   0      0  0
# 48             122      R   2019-10-04   55000000   0      0  1

# %%
df_ratings
# Out:
#                 Movie Title  Domestic Gross  Runtime (mins) Rating  \
# 0         Bad Boys for Life     204417855.0           124.0      R
# 1                      1917     159227644.0           119.0      R
# 2        Sonic the Hedgehog     146066470.0            99.0     PG
# 3   Jumanji: The Next Level     316831246.0           123.0  PG-13
# 4     Star Wars: Episode IX     515202542.0           142.0  PG-13
# ..                      ...             ...             ...    ...
# 44                      NaN             NaN             NaN    NaN
# 45                      NaN             NaN             NaN    NaN
# 46                      NaN             NaN             NaN    NaN
# 47                      NaN             NaN             NaN    NaN
# 48                      NaN             NaN             NaN    NaN
#
#    Release Date       Budget   PG  PG-13    R
# 0    2020-01-17   90000000.0  NaN    NaN  NaN
# 1    2019-12-25   95000000.0  NaN    NaN  NaN
# 2    2020-02-14   85000000.0  NaN    NaN  NaN
# 3    2019-12-13  125000000.0  NaN    NaN  NaN
# 4    2019-12-20  275000000.0  NaN    NaN  NaN
# ..          ...          ...  ...    ...  ...
# 44          NaT          NaN  0.0    0.0  1.0
# 45          NaT          NaN  0.0    0.0  1.0
# 46          NaT          NaN  0.0    0.0  0.0
# 47          NaT          NaN  0.0    0.0  0.0
# 48          NaT          NaN  0.0    0.0  1.0
#
# [98 rows x 9 columns]
